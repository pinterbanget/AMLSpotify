# %% [markdown]
# # AML Spotify EDA
#
# #AntiMLPRMLPRClub

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Spotify_Dataset_V3.csv', delimiter=';')
data.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# ...

# %%
data[data["Artists"] == "Billie Eilish"]
# Out:
#         Rank           Title        Artists        Date  Danceability  Energy  \
# 4019     153  hotline (edit)  Billie Eilish  16/05/2023         0.516   0.254
# 4340     184  hotline (edit)  Billie Eilish  15/05/2023         0.516   0.254
# 5085      95  hotline (edit)  Billie Eilish  12/05/2023         0.516   0.254
# 5335      73  hotline (edit)  Billie Eilish  11/05/2023         0.516   0.254
# 31534    185              TV  Billie Eilish  09/02/2023         0.412   0.236
# ...      ...             ...            ...         ...           ...     ...
# 506290   146      ocean eyes  Billie Eilish  21/06/2018         0.511   0.363
# 506561   161      ocean eyes  Billie Eilish  20/06/2018         0.511   0.363
# 506823   183      ocean eyes  Billie Eilish  19/06/2018         0.511   0.363
# 507103   163      ocean eyes  Billie Eilish  18/06/2018         0.511   0.363
# 507381   181      ocean eyes  Billie Eilish  17/06/2018         0.511   0.363
#
# ...

# %% [markdown]
# Remark: ini regionnya mana jir? US itu Billie dr US kan? Testing hypothesis: panggil artist asal UK

# %%
data[data["Artists"] == "Ed Sheeran"]
# Out:
#         Rank              Title     Artists        Date  Danceability  Energy  \
# 138       93        Eyes Closed  Ed Sheeran  29/05/2023         0.793   0.520
# 139       94            Perfect  Ed Sheeran  29/05/2023         0.599   0.448
# 245      164       Shape of You  Ed Sheeran  29/05/2023         0.825   0.652
# 280      192            Shivers  Ed Sheeran  29/05/2023         0.788   0.859
# 432       92            Perfect  Ed Sheeran  28/05/2023         0.599   0.448
# ...      ...                ...         ...         ...           ...     ...
# 651384   109  Thinking out Loud  Ed Sheeran  03/01/2017         0.781   0.445
# 651573    91         Photograph  Ed Sheeran  02/01/2017         0.614   0.379
# 651641   109  Thinking out Loud  Ed Sheeran  02/01/2017         0.781   0.445
# 651848   123         Photograph  Ed Sheeran  01/01/2017         0.614   0.379
# 651868   141  Thinking out Loud  Ed Sheeran  01/01/2017         0.781   0.445
#
# ...

# %% [markdown]
# Sudah kuduga, jadi ini pasti data Global Chart. Testing hypothesis: cari Anggi Marito

# %%
data[data["Artists"] == "Anggi Marito"]
# Out:
#       Rank              Title       Artists        Date  Danceability  Energy  \
# 100     66  Tak Segampang Itu  Anggi Marito  29/05/2023         0.506   0.438
# 382     56  Tak Segampang Itu  Anggi Marito  28/05/2023         0.506   0.438
# 708     76  Tak Segampang Itu  Anggi Marito  27/05/2023         0.506   0.438
# 1026    87  Tak Segampang Itu  Anggi Marito  26/05/2023         0.506   0.438
# 1305    77  Tak Segampang Itu  Anggi Marito  25/05/2023         0.506   0.438
# 1587    72  Tak Segampang Itu  Anggi Marito  24/05/2023         0.506   0.438
# 1879    75  Tak Segampang Itu  Anggi Marito  23/05/2023         0.506   0.438
# 2173    77  Tak Segampang Itu  Anggi Marito  22/05/2023         0.506   0.438
# 2439    60  Tak Segampang Itu  Anggi Marito  21/05/2023         0.506   0.438
# 2758    81  Tak Segampang Itu  Anggi Marito  20/05/2023         0.506   0.438
# 3065    91  Tak Segampang Itu  Anggi Marito  19/05/2023         0.506   0.438
# ...

# %% [markdown]
# Buset ternyata pernah chart global juga

# %% [markdown]
# ## Analysis ideas (free to add)
#
# - Give an artist name. In which position should they appear kl mereka drop lagu di 2024?
#     - Ini menarik karena nanti kita mesti bikin asumsi2 dulu, contoh ngechart di 2023 bakal lebih mungkin ngechart ketimbang ngechart di 2017
#     - Challenge bakal ada di proses data2 supaya artis2 yang collab jg diperhitungkan
#
# - Time series analysis: summer season vs. tracks with high danceability/energy? Winter season vs. Christmas songs appearing?
#
# - Insane mode: scrape data2 berita dan cek korelasi berita vs. posisi chart. Contoh: Oasis kemaren masuk chart Global perkara reuni + announce tour dates.
#
# - What makes a song "stay" in the charts? Bisa ga kita prediksi berdasarkan nilai2 yang ada? I think we also need to create an arbitrary rank based on the artist
